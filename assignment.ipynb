# %%
import pandas as pd
import numpy as np

data = pd.read_csv('assignment.csv')
print(data.describe())
X = data['year experience']
Y = data['salary']
mean_x = np.mean(X)
mean_y = np.mean(Y)
size = len(X)

numerator = 0
denominator = 0
for i in range(size):
    numerator += (X[i] - mean_x)*(Y[i] - mean_y)
    denominator += (X[i]-mean_x) ** 2
m = numerator/denominator
c = mean_y - (m * mean_x)
c
# Out:
#        year experience        salary
# count       101.000000    101.000000
# mean         50.059406   7425.742574
# std          29.203706   6348.773952
# min           1.000000   3000.000000
# 25%          25.000000   4000.000000
# 50%          50.000000   5000.000000
# 75%          75.000000   5000.000000
# max         100.000000  20000.000000
# 7680.222432477928

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

x = np.linspace(min_x, max_x, 1000)
y =  m*x + c

import matplotlib.pyplot as plt

plt.plot(x, y, color='Blue', label='Regression Line')
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('Experience')
plt.ylabel('Salary')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n = 0
d = 0
for i in range(size):
    y_pred = m * X[i] + c
    n += (y_pred-mean_y) **2
    d += (Y[i] - mean_y) **2
r_square = n/d
r_square
# Out:
# 0.0005468039556929831
